# %%
import pickle
#libraury we need to import

# %%
loaded_model=pickle.load(open("Salary_predict_finalmodel.sav",'rb'))
result=loaded_model.predict([[20]])
#saved output
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[213982.61706507]])

# %%
#next we try freshers salary so give experience 0

# %%
loaded_model=pickle.load(open("Salary_predict_finalmodel.sav",'rb'))
result=loaded_model.predict([[0]])
#saved output
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])

# %%
# is a slop starting point
